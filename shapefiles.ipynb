# %%
import geopandas as gpd

# %%
file_path = r'/Users/rohan/Downloads/Fire Perimeters PostfireVegChg/S_USA.Fire_RAVG_Perimeters_PostfireVegChg.shp'
shp = gpd.read_file(file_path)

# %%
type(shp)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
shp.head()
# Out:
#                 EVENT_ID      FIRE_NAME FIRE_YEAR     ACRES ASMNT_TYPE  \
# 0  ID4677111546320210708      BAR CREEK      2021   1623.99    Initial
# 1  ID4685611616820210707  JOHNSON CREEK      2021   1377.22    Initial
# 2  ID4694511659020210708  SAND MOUNTAIN      2021   1607.05    Initial
# 3  ID4697111565820210707  DEVILS PULPIT      2021   3064.71    Initial
# 4  ID4716911544120210707     TUMBLEDOWN      2021  11203.23    Initial
#
#   PREIMGYMD POSTIMGYMD UPDATE_YMD  TREE_ACRES  TREE_AC_50  TREE_AC_75  \
# 0  20200921   20210924   20221223   1607.7296    243.9728    159.4608
# 1  20190904   20210829   20221223   1375.0992     58.4912     36.0288
# 2  20200903   20210906   20221223   1462.9472    244.6400    200.6048
# 3  20201003   20211003   20221223   3029.5328    122.7648     72.7248
# 4  20201003   20211003   20221223  10623.1584   4365.0448   3852.8576
#
#          EVT_VER  SHAPE_AREA  SHAPE_LEN  \
# 0  LF2020_EVT220    0.000774   0.194285
# ...

# %%
shp
# Out:
#                    EVENT_ID      FIRE_NAME FIRE_YEAR     ACRES ASMNT_TYPE  \
# 0     ID4677111546320210708      BAR CREEK      2021   1623.99    Initial
# 1     ID4685611616820210707  JOHNSON CREEK      2021   1377.22    Initial
# 2     ID4694511659020210708  SAND MOUNTAIN      2021   1607.05    Initial
# 3     ID4697111565820210707  DEVILS PULPIT      2021   3064.71    Initial
# 4     ID4716911544120210707     TUMBLEDOWN      2021  11203.23    Initial
# ...                     ...            ...       ...       ...        ...
# 1153  ID4578011507120220830        3 PRONG      2022   4997.66    Initial
# 1154  ID4578511471120220708   INDIAN RIDGE      2022   9705.66    Initial
# 1155  ID4581211499720220821   LYNX MEADOWS      2022   1629.02    Initial
# 1156  ID4627511548320220812       VAN CAMP      2022   3557.53    Initial
# 1157  ID4636111481620220831   WARM SPRINGS      2022   5865.10    Initial
#
#      PREIMGYMD POSTIMGYMD UPDATE_YMD  TREE_ACRES  TREE_AC_50  TREE_AC_75  \
# ...

# %%
shp.plot(legend=True)
# Out:
# <Axes: >

# %%
shp["FIRE_YEAR"].value_counts()
# Out:
# FIRE_YEAR
# 2017    157
# 2015    128
# 2018    119
# 2021    118
# 2016    111
# 2020     97
# 2019     80
# 2012     79
# 2023     79
# 2022     78
# 2014     56
# 2013     56
# Name: count, dtype: int64

# %%
shp["ASMNT_TYPE"].value_counts()
# Out:
# ASMNT_TYPE
# Initial     1037
# Extended     121
# Name: count, dtype: int64

# %%
shp["PREIMGYMD"].value_counts()
# Out:
# PREIMGYMD
# 20151022    24
# 20141007    22
# 20160910    21
# 20110920    13
# 20110929    13
#             ..
# 20190714     1
# 20190726     1
# 20190705     1
# 20181115     1
# 20210930     1
# Name: count, Length: 622, dtype: int64

# %%
shp["POSTIMGYMD"].value_counts()
# Out:
# POSTIMGYMD
# 20170929    33
# 20171027    26
# 20151010    26
# 20151017    15
# 20210924    10
#             ..
# 20200920     1
# 20200802     1
# 20201114     1
# 20200826     1
# 20221018     1
# Name: count, Length: 603, dtype: int64

# %%
shp["TREE_ACRES"].mean()
# Out:
# 18908.925641450776

# %%
shp["TREE_ACRES"].describe()
# Out:
# count      1158.000000
# mean      18908.925641
# std       49072.953708
# min           0.000000
# 25%        2176.740000
# 50%        4925.048000
# 75%       14682.458800
# max      811175.755200
# Name: TREE_ACRES, dtype: float64

# %%
shp["TREE_AC_50"].value_counts()
# Out:
# TREE_AC_50
# 0.0000        23
# 7.5616         3
# 5.5600         3
# 28.2448        3
# 2.8912         3
#               ..
# 2833.5984      1
# 12040.5136     1
# 862.4672       1
# 2300.7280      1
# 212.1696       1
# Name: count, Length: 1085, dtype: int64

# %%
shp["TREE_AC_50"].describe()
# Out:
# count      1158.000000
# mean       8251.654769
# std       24298.132245
# min           0.000000
# 25%         329.541200
# 50%        1549.016000
# 75%        5836.999200
# max      433542.556800
# Name: TREE_AC_50, dtype: float64

# %%
shp["TREE_AC_75"].value_counts()
# Out:
# TREE_AC_75
# 0.0000       32
# 0.2224       11
# 2.2240        5
# 2.6688        4
# 1.7792        4
#              ..
# 821.7680      1
# 1618.8496     1
# 486.8336      1
# 848.6784      1
# 2330.0848     1
# Name: count, Length: 1061, dtype: int64

# %%
shp["TREE_AC_75"].describe()
# Out:
# count      1158.000000
# mean       7099.455489
# std       21472.783116
# min           0.000000
# 25%         219.397600
# 50%        1263.454400
# 75%        4875.063600
# max      386104.414400
# Name: TREE_AC_75, dtype: float64

# %%
shp
# Out:
#                    EVENT_ID      FIRE_NAME FIRE_YEAR     ACRES ASMNT_TYPE  \
# 0     ID4677111546320210708      BAR CREEK      2021   1623.99    Initial
# 1     ID4685611616820210707  JOHNSON CREEK      2021   1377.22    Initial
# 2     ID4694511659020210708  SAND MOUNTAIN      2021   1607.05    Initial
# 3     ID4697111565820210707  DEVILS PULPIT      2021   3064.71    Initial
# 4     ID4716911544120210707     TUMBLEDOWN      2021  11203.23    Initial
# ...                     ...            ...       ...       ...        ...
# 1153  ID4578011507120220830        3 PRONG      2022   4997.66    Initial
# 1154  ID4578511471120220708   INDIAN RIDGE      2022   9705.66    Initial
# 1155  ID4581211499720220821   LYNX MEADOWS      2022   1629.02    Initial
# 1156  ID4627511548320220812       VAN CAMP      2022   3557.53    Initial
# 1157  ID4636111481620220831   WARM SPRINGS      2022   5865.10    Initial
#
#      PREIMGYMD POSTIMGYMD UPDATE_YMD  TREE_ACRES  TREE_AC_50  TREE_AC_75  \
# ...

# %%
shp.plot(cmap='coolwarm')
# Out:
# <Axes: >

# %%
shp.to_csv("shp_f.csv")

# %%
shp
# Out:
#                    EVENT_ID      FIRE_NAME FIRE_YEAR     ACRES ASMNT_TYPE  \
# 0     ID4677111546320210708      BAR CREEK      2021   1623.99    Initial
# 1     ID4685611616820210707  JOHNSON CREEK      2021   1377.22    Initial
# 2     ID4694511659020210708  SAND MOUNTAIN      2021   1607.05    Initial
# 3     ID4697111565820210707  DEVILS PULPIT      2021   3064.71    Initial
# 4     ID4716911544120210707     TUMBLEDOWN      2021  11203.23    Initial
# ...                     ...            ...       ...       ...        ...
# 1153  ID4578011507120220830        3 PRONG      2022   4997.66    Initial
# 1154  ID4578511471120220708   INDIAN RIDGE      2022   9705.66    Initial
# 1155  ID4581211499720220821   LYNX MEADOWS      2022   1629.02    Initial
# 1156  ID4627511548320220812       VAN CAMP      2022   3557.53    Initial
# 1157  ID4636111481620220831   WARM SPRINGS      2022   5865.10    Initial
#
#      PREIMGYMD POSTIMGYMD UPDATE_YMD  TREE_ACRES  TREE_AC_50  TREE_AC_75  \
# ...

# %%
shp
# Out:
#           FIRE_NAME FIRE_YEAR     ACRES  TREE_ACRES  TREE_AC_50  TREE_AC_75  \
# 0         BAR CREEK      2021   1623.99   1607.7296    243.9728    159.4608
# 1     JOHNSON CREEK      2021   1377.22   1375.0992     58.4912     36.0288
# 2     SAND MOUNTAIN      2021   1607.05   1462.9472    244.6400    200.6048
# 3     DEVILS PULPIT      2021   3064.71   3029.5328    122.7648     72.7248
# 4        TUMBLEDOWN      2021  11203.23  10623.1584   4365.0448   3852.8576
# ...             ...       ...       ...         ...         ...         ...
# 1153        3 PRONG      2022   4997.66   4203.1376   2379.0128   2073.2128
# 1154   INDIAN RIDGE      2022   9705.66   8165.1936   2882.0816   2297.1696
# 1155   LYNX MEADOWS      2022   1629.02   1314.6064    430.1216    351.1696
# 1156       VAN CAMP      2022   3557.53   3509.4720    212.1696    156.7920
# 1157   WARM SPRINGS      2022   5865.10   5370.5152   2774.6624   2330.0848
#
# ...
